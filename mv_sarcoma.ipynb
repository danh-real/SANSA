# %%
from shutil import copy
from glob import glob
from os.path import join

# %%
root = "/data/datasets/Sarcoma"
subsets = {"Mass": "16_NIFTI_Soft-tissue-Sarcoma-Mass", "Edema": "17_NIFTI_Soft-tissue-Sarcoma-Edema"}

train_split = [
    "STS_001",  "STS_008",  "STS_015",  "STS_021",  "STS_028",  "STS_033",  "STS_039",  "STS_046",
    "STS_003",  "STS_010",  "STS_016",  "STS_022",  "STS_029",  "STS_035",  "STS_040",  "STS_047",
    "STS_004",  "STS_011",  "STS_017",  "STS_023",  "STS_030",  "STS_036",  "STS_041",  "STS_048",
    "STS_006",  "STS_012",  "STS_018",  "STS_024",  "STS_031",  "STS_037",  "STS_042",  "STS_049",
    "STS_007",  "STS_013",  "STS_019",  "STS_027",  "STS_032",  "STS_038",  "STS_043",  "STS_051",
]

test_split = [
    "STS_002",  "STS_009",  "STS_020",  "STS_026",  "STS_044",  "STS_050",
    "STS_005",  "STS_014",  "STS_025",  "STS_034",  "STS_045",
]

# %%
# for k, subset in subsets.items():
#     for case in glob(join(root, subset, "MRI", "*")):
#         impath = join(case, "img", "image.nii.gz")
#         gtpath = join(case, "label", f"mask_GTV_{k}.nii.gz")

#         case_id = case.split("/")[-1]

#         if case_id in train_split:
#             dst_impath = join(root, "imagesTr", f"{case_id}_{k}.nii.gz")
#             dst_gtpath = join(root, "labelsTr", f"{case_id}_{k}.nii.gz")
#             copy(impath, dst_impath)
#             copy(gtpath, dst_gtpath)
#         else:
#             dst_impath = join(root, "imagesTs", f"{case_id}_{k}.nii.gz")
#             dst_gtpath = join(root, "labelsTs", f"{case_id}_{k}.nii.gz")
#             copy(impath, dst_impath)
#             copy(gtpath, dst_gtpath)

# %%
import os

int(float(os.path.splitext("/data/code/SANSA/data/MSD/Task01_BrainTumour/imagesTr/BRATS_004/slice_060_1.0.png")[0].split("_")[-1]))
# Out:
# 1
